# %%
import pandas as pd

data = pd.read_csv("/home/simplon/premier-dossier/exo_netflix/netflix_titles.csv")

# %%
import pandas as pd 
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://Simplon:simplon123!@localhost:3306/exo_netflix')

# %%
data.head()
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
# 3  80058654  TV Show         Transformers: Robots in Disguise
# 4  80125979    Movie                             #realityhigh
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4          Fernando Lebrija
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
# 3  Will Friedle, Darren Criss, Constance Zimmer, ...
# 4  Nesta Cooper, Kate Walsh, John Michael Higgins...
#
#                                     country         date_added  release_year  \
# ...

# %%
data.shape
# Out:
# (6234, 12)

# %%
"""
listec = []
for i in liste222:
    print(i)
    print(len(i))
    if len(i)>1:
        for j in range(len(i)):
            print(i[j])
            listec.append(i[j])
            #print(i[j])
            #print(i)
    else:
        listec.append(i)
"""
# Out:
# ['Children & Family Movies', ' Comedies']
# 2
# Children & Family Movies
#  Comedies
# ['Stand-Up Comedy']
# 1
# ["Kids' TV"]
# 1
# ["Kids' TV"]
# 1
# ['Comedies']
# 1
# ['Crime TV Shows', ' International TV Shows', ' Spanish-Language TV Shows']
# 3
# Crime TV Shows
#  International TV Shows
#  Spanish-Language TV Shows
# ['International Movies', ' Sci-Fi & Fantasy', ' Thrillers']
# 3
# International Movies
#  Sci-Fi & Fantasy
#  Thrillers
# ['Stand-Up Comedy']
# 1
# ['Docuseries', ' Science & Nature TV']
# 2
# Docuseries
#  Science & Nature TV
# ['Action & Adventure', ' Thrillers']
# 2
# Action & Adventure
#  Thrillers
# ['Stand-Up Comedy']
# 1
# ['Action & Adventure', ' Dramas', ' International Movies']
# 3
# Action & Adventure
#  Dramas
#  International Movies
# ['Children & Family Movies']
# 1
# ['Children & Family Movies']
# 1
# ['Children & Family Movies']
# 1
# ['Children & Family Movies']
# 1
# ['Children & Family Movies']
# 1
# ['Children & Family Movies']
# 1
# ...

# %%
# correction question 20

tmp2 = data.loc[data["listed_in"].notna()][['show_id', 'listed_in']]



show_listed_in = pd.DataFrame(columns = ['show_id', 'listed_in'])


show_listed_in

for i in range(tmp2.shape[0]):
    tmp = tmp2.iloc[i]["listed_in"].split(", ")
    show_id = [tmp2.iloc[i]["show_id"]]*len(tmp)
    df = pd.DataFrame({'show_id': show_id,
                   'listed_in': tmp}, columns = ['show_id', 'listed_in'])
    show_listed_in = show_listed_in.append(df, ignore_index=True)

show_listed_in
# Out:
#         show_id                 listed_in
# 0      81145628  Children & Family Movies
# 1      81145628                  Comedies
# 2      80117401           Stand-Up Comedy
# 3      70234439                  Kids' TV
# 4      80058654                  Kids' TV
# ...         ...                       ...
# 13665  70281022          British TV Shows
# 13666  70281022               TV Comedies
# 13667  70281022                 TV Dramas
# 13668  70153404         Classic & Cult TV
# 13669  70153404               TV Comedies
#
# [13670 rows x 2 columns]

# %%
##### correction question 21

listed_in = show_listed_in['listed_in'].drop_duplicates().reset_index(drop=True).reset_index()
listed_in = listed_in.rename(columns={"index": "listed_in_id"})
show_listed_in = show_listed_in.merge(listed_in, left_on='listed_in', right_on='listed_in', how='left')
del show_listed_in['listed_in']

# %%
show_listed_in
# Out:
#         show_id  listed_in_id
# 0      81145628             0
# 1      81145628             1
# 2      80117401             2
# 3      70234439             3
# 4      80058654             3
# ...         ...           ...
# 13665  70281022            24
# 13666  70281022            20
# 13667  70281022            21
# 13668  70153404            41
# 13669  70153404            20
#
# [13670 rows x 2 columns]

# %%
catalogue_categorie = show_listed_in

# %%
catalogue_categorie = catalogue_categorie.rename(columns = {'listed_in_id': 'ca_id_fk', 'show_id': 'show_id_fk'})

# %%
catalogue_categorie.to_sql('catalogue_categorie', con=engine, if_exists='append', index=False)

# %%
show_listed_in = show_listed_in.drop_duplicates()

# %%
Categorie = show_listed_in
Categorie
# Out:
#                          listed_in  listed_in_id
# 0         Children & Family Movies             0
# 1                         Comedies             1
# 2                  Stand-Up Comedy             2
# 3                         Kids' TV             3
# 6                   Crime TV Shows             4
# 7           International TV Shows             5
# 8        Spanish-Language TV Shows             6
# 9             International Movies             7
# 10                Sci-Fi & Fantasy             8
# 11                       Thrillers             9
# 13                      Docuseries            10
# 14             Science & Nature TV            11
# 15              Action & Adventure            12
# 19                          Dramas            13
# 28                     Cult Movies            14
# 30              Independent Movies            15
# 33                 Romantic Movies            16
# 37                   Documentaries            17
# ...

# %%
Categorie = Categorie.rename(columns = {'listed_in_id': 'ca_id', 'listed_in': 'listed_in'})

# %%
Categorie.to_sql('Categorie', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     196                                          self.max_stmt_length,
# ...

# %%
# 21 -> director
tmp2 = data.loc[data["director"].notna()][['show_id', 'director']]



Director = pd.DataFrame(columns = ['show_id', 'director'])

for i in range(tmp2.shape[0]):
    tmp = tmp2.iloc[i]["director"].split(", ")
    show_id = [tmp2.iloc[i]["show_id"]]*len(tmp)
    df = pd.DataFrame({'show_id': show_id,
                   'director': tmp}, columns = ['show_id', 'director'])
    Director = Director.append(df, ignore_index=True)

Director
# Out:
#        show_id              director
# 0     81145628          Richard Finn
# 1     81145628            Tim Maltby
# 2     80125979      Fernando Lebrija
# 3     70304989           Gabe Ibáñez
# 4     80164077          Rodrigo Toro
# ...        ...                   ...
# 4847  80164216         Thomas Astruc
# 4848  80115328  Vikramaditya Motwane
# 4849  80115328        Anurag Kashyap
# 4850  80176842            Jung-ah Im
# 4851  80126599             Onur Ünlü
#
# [4852 rows x 2 columns]

# %%
# directors_catalogue = pd.DataFrame(columns = ['di_id', 'director'])

directors_catalogue = Director.append(df, ignore_index=True)

director = Director['director'].drop_duplicates().reset_index(drop=True).reset_index()
director = director.rename(columns={"index": "director_id"})
directors_catalogue = directors_catalogue.merge(director, left_on='director', right_on='director', how='inner')
del directors_catalogue['director']

# %%
directors_catalogue = directors_catalogue.drop_duplicates()

# %%
directors_catalogue
# Out:
#        show_id  director_id
# 0     81145628            0
# 1     81145628            1
# 2     81065331            1
# 3     80125979            2
# 4     70304989            3
# ...        ...          ...
# 4847  80176929         3651
# 4848  80176842         3651
# 4849  80176929         3652
# 4850  80063224         3653
# 4851  80126599         3654
#
# [4851 rows x 2 columns]

# %%
# -> 21 cast

tmp2 = data.loc[data["cast"].notna()][['show_id', 'cast']]



show_cast = pd.DataFrame(columns = ['show_id', 'cast'])



for i in range(tmp2.shape[0]):
    tmp = tmp2.iloc[i]["cast"].split(", ")
    show_id = [tmp2.iloc[i]["show_id"]]*len(tmp)
    df = pd.DataFrame({'show_id': show_id, 'cast': tmp}, columns = ['show_id', 'cast'])
    show_cast = show_cast.append(df, ignore_index=True)

show_cast
# Out:
#         show_id              cast
# 0      81145628     Alan Marriott
# 1      81145628       Andrew Toth
# 2      81145628      Brian Dobson
# 3      81145628       Cole Howard
# 4      81145628  Jennifer Cameron
# ...         ...               ...
# 44306  70153404     Courteney Cox
# 44307  70153404       Lisa Kudrow
# 44308  70153404      Matt LeBlanc
# 44309  70153404     Matthew Perry
# 44310  70153404   David Schwimmer
#
# [44311 rows x 2 columns]

# %%
cast = show_cast['cast'].drop_duplicates().reset_index(drop=True).reset_index()
cast = cast.rename(columns={"index": "cast_id"})
show_cast = show_cast.merge(cast, left_on='cast', right_on='cast', how='inner')
del show_cast['cast']

# %%
#show_cast = show_cast.drop_duplicates()
show_cast
# Out:
#         show_id  cast_id
# 0      81145628        0
# 1      81065331        0
# 2      70109891        0
# 3      81145628        1
# 4      80191075        1
# ...         ...      ...
# 44306  70281022    27400
# 44307  70281022    27401
# 44308  70281022    27402
# 44309  70281022    27403
# 44310  70153404    27404
#
# [44311 rows x 2 columns]

# %%
catalogue_actor = show_cast

# %%
catalogue_actor = catalogue_actor.rename(columns = {'show_id': 'show_id_fk', 'cast_id': 'A_id_fk'})

# %%
catalogue_actor.to_sql('catalogue_actor', con=engine, if_exists='append', index=False)

# %%
Actor = show_cast
Actor
# Out:
#                    cast  cast_id
# 0         Alan Marriott        0
# 3           Andrew Toth        1
# 6          Brian Dobson        2
# 11          Cole Howard        3
# 14     Jennifer Cameron        4
# ...                 ...      ...
# 44306   Rosie Cavaliero    27400
# 44307  Vicki Pepperdine    27401
# 44308   Margaret Clunie    27402
# 44309         Tim Steed    27403
# 44310     Matthew Perry    27404
#
# [27405 rows x 2 columns]

# %%
Actor = Actor.rename(columns = {'cast_id': 'A_id', 'cast': 'cast'})

# %%
Actor.to_sql('Actor', con=engine, if_exists='append', index=False)

# %%
# -> 21 country

tmp2 = data.loc[data["country"].notna()][['show_id', 'country']]



show_country = pd.DataFrame(columns = ['show_id', 'country'])



for i in range(tmp2.shape[0]):
    tmp = tmp2.iloc[i]["country"].split(", ")
    show_id = [tmp2.iloc[i]["show_id"]]*len(tmp)
    df = pd.DataFrame({'show_id': show_id, 'country': tmp}, columns = ['show_id', 'country'])
    show_country = show_country.append(df, ignore_index=True)

show_country
# Out:
#        show_id         country
# 0     81145628   United States
# 1     81145628           India
# 2     81145628     South Korea
# 3     81145628           China
# 4     80117401  United Kingdom
# ...        ...             ...
# 7174  80005756       Australia
# 7175  80000063   United States
# 7176  70286564   United States
# 7177  70281022  United Kingdom
# 7178  70153404   United States
#
# [7179 rows x 2 columns]

# %%
country = show_country['country'].drop_duplicates().reset_index(drop=True).reset_index()
country = country.rename(columns={"index": "country_id"})
show_country = show_country.merge(country, left_on='country', right_on='country', how='inner')
del show_country['country']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'country'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-1515dbb20f29> in <module>
# ...

# %%
show_country
# Out:
#        show_id  country_id
# 0     81145628           0
# 1     70234439           0
# 2     80058654           0
# 3     80125979           0
# 4     70304989           0
# ...        ...         ...
# 7174  70308278         108
# 7175  70308278         109
# 7176  80217848         110
# 7177  80217848         111
# 7178  80162994         112
#
# [7179 rows x 2 columns]

# %%
show_country  = show_country .rename(columns = {'show_id': 'show_id_fk', 'country_id': 'co_id_fk'})

# %%
country_catalogue = show_country

# %%
country_catalogue.to_sql('country_catalogue', con=engine, if_exists='append', index=False)

# %%
country_catalogue
# Out:
#      show_id_fk  co_id_fk
# 0      81145628         0
# 1      70234439         0
# 2      80058654         0
# 3      80125979         0
# 4      70304989         0
# ...         ...       ...
# 7174   70308278       108
# 7175   70308278       109
# 7176   80217848       110
# 7177   80217848       111
# 7178   80162994       112
#
# [7179 rows x 2 columns]

# %%
Country = Country.rename(columns = {'country_id': 'co_id', 'country': 'country'})

# %%
Country.to_sql('Country', con=engine, if_exists='append', index=False)

# %%
Country = Country.drop_duplicates()

# %%
data.to_sql('Categorie', con=engine, index = False,if_exists = 'append')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-714405291314> in <module>
# ----> 1 engine = data.to_sql('Categorie', con=engine, index = False,if_exists = 'append')
#
# NameError: name 'engine' is not defined

# %%
data['duration'] = data['duration'].str.replace(" min", "").str.replace(" Season", "").str.replace(" season", "").str.replace("s", "").astype(int)
data['release_year']=pd.to_datetime(data['release_year'])

# %%
data.release_year
# Out:
# 0       2019
# 1       2016
# 2       2013
# 3       2016
# 4       2017
#         ...
# 6229    2015
# 6230    2016
# 6231    2016
# 6232    2013
# 6233    2003
# Name: release_year, Length: 6234, dtype: int64

# %%
#Director

Director.to_sql('Director', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     196                                          self.max_stmt_length,
# ...

# %%
directors_catalogue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-95-55caf2dcc43a> in <module>
# ----> 1 directors_catalogue
#
# NameError: name 'directors_catalogue' is not defined

# %%
directors_catalogue.to_sql('directors_catalogue', con=engine, if_exists='append', index=False)

# %%
directors_catalogue = directors_catalogue.rename(columns = {'show_id': 'show_id_fk', 'director_id': 'di_id_fk'})

# %%
directors_catalogue
# Out:
#      show_id_fk  di_id_fk
# 0      81145628         0
# 1      81145628         1
# 2      81065331         1
# 3      80125979         2
# 4      70304989         3
# ...         ...       ...
# 4847   80176929      3651
# 4848   80176842      3651
# 4849   80176929      3652
# 4850   80063224      3653
# 4851   80126599      3654
#
# [4851 rows x 2 columns]

# %%
Directors = directors_catalogue

# %%
Directors = Directors.rename(columns = {'director_id': 'di_id', 'director': 'director'})

# %%
Directors = Directors.drop_duplicates()
Directors
# Out:
#               director  di_id
# 0         Richard Finn      0
# 1           Tim Maltby      1
# 3     Fernando Lebrija      2
# 4          Gabe Ibáñez      3
# 5         Rodrigo Toro      4
# ...                ...    ...
# 4846       James Hawes   3650
# 4847        Jung-ah Im   3651
# 4849       Seung-uk Jo   3652
# 4850   Andy Devonshire   3653
# 4851         Onur Ünlü   3654
#
# [3655 rows x 2 columns]

# %%
#Director

Directors.to_sql('Directors', con=engine, if_exists='append', index=False)

# %%
directors_catalogue.drop_duplicates()
directors_catalogue
# Out:
#               director  director_id
# 0         Richard Finn            0
# 1           Tim Maltby            1
# 2           Tim Maltby            1
# 3     Fernando Lebrija            2
# 4          Gabe Ibáñez            3
# ...                ...          ...
# 4848        Jung-ah Im         3651
# 4849       Seung-uk Jo         3652
# 4850   Andy Devonshire         3653
# 4851         Onur Ünlü         3654
# 4852         Onur Ünlü         3654
#
# [4853 rows x 2 columns]

# %%
Directors = Directors.merge(directors_catalogue, left_on='director', right_on='show_id_fk', how='inner')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-6c819c503c49> in <module>
# ----> 1 Directors = Directors.merge(directors_catalogue, left_on='director', right_on='show_id_fk', how='inner')
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7295             copy=copy,
#    7296             indicator=indicator,
# -> 7297             validate=validate,
#    7298         )
#    7299
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
#      88     return op.get_result()
#
# ...

# %%
Directors
# Out:
#          di_id              director
# 0     81145628          Richard Finn
# 1     81145628            Tim Maltby
# 2     80125979      Fernando Lebrija
# 3     70304989           Gabe Ibáñez
# 4     80164077          Rodrigo Toro
# ...        ...                   ...
# 4847  80164216         Thomas Astruc
# 4848  80115328  Vikramaditya Motwane
# 4849  80115328        Anurag Kashyap
# 4850  80176842            Jung-ah Im
# 4851  80126599             Onur Ünlü
#
# [4852 rows x 2 columns]

# %%
Directors.to_sql('Directors', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1225                     self.dialect.do_executemany(
# -> 1226                         cursor, statement, parameters, context
#    1227                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#
# ~/anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     196                                          self.max_stmt_length,
# ...

# %%
directors_catalogue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-94-55caf2dcc43a> in <module>
# ----> 1 directors_catalogue
#
# NameError: name 'directors_catalogue' is not defined

# %%
show_director
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-4da10b18f24c> in <module>
# ----> 1 show_director
#
# NameError: name 'show_director' is not defined

# %%
#df.to_sql('catalogue', con=engine, if_exists='append', index=False)
#country.to_sql('country', con=engine, if_exists='append', index=False)
#cast.to_sql('cast', con=engine, if_exists='append', index=False)
#dir.to_sql('directors', con=engine, if_exists='append', index=False)

# %%
catalogue = data[['show_id','type', 'title', 'date_added', 'release_year', 'rating', 'duration', 'description']]

# %%
catalogue
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#      date_added                  release_year    rating  \
# 0    2019-09-09 1970-01-01 00:00:00.000002019     TV-PG
# ...

# %%
catalogue['duration'] = data['duration']
# Out:
# /home/simplon/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
catalogue.to_sql('catalogue', con=engine, if_exists='append', index=False)

# %%
data
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       director  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
type(catalogue.iloc[163]['description'])
# Out:
# str

# %%
data['duration'] = data['duration'].str.replace(" min", "").str.replace(" Season", "").str.replace(" season", "").str.replace("s", "").astype(int)
data['release_year']=pd.to_datetime(data['release_year'])

# %%
catalogue['date_added']=pd.to_datetime(catalogue['date_added'])
# Out:
# /home/simplon/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
type(catalogue.iloc[1]['date_added'])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
catalogue.iloc[1]['date_added']
# Out:
# Timestamp('2016-09-09 00:00:00')

# %%
catalogue['date_added']
# Out:
# 0      2019-09-09
# 1      2016-09-09
# 2      2018-09-08
# 3      2018-09-08
# 4      2017-09-08
#           ...
# 6229          NaT
# 6230          NaT
# 6231          NaT
# 6232          NaT
# 6233          NaT
# Name: date_added, Length: 6234, dtype: datetime64[ns]

# %%
catalogue
# Out:
#        show_id     type                                        title  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#      date_added                  release_year    rating  duration  \
# 0    2019-09-09 1970-01-01 00:00:00.000002019     TV-PG        90
# ...

# %%
# -> Locasise une ligne d'une Serie ou d'un DataFrame
# renvoie sous forme de series

data.loc[1]
# Out:
# show_id                                                  80117401
# type                                                        Movie
# title                                  Jandino: Whatever it Takes
# director                                                      NaN
# cast                                             Jandino Asporaat
# country                                            United Kingdom
# date_added                                      September 9, 2016
# release_year                                                 2016
# rating                                                      TV-MA
# duration                                                   94 min
# listed_in                                         Stand-Up Comedy
# description     Jandino Asporaat riffs on the challenges of ra...
# Name: 1, dtype: object

# %%
# -> Locasise plusieurs lignes d'une Serie ou d'un DataFrame
# renvoie sous forme de DataFrame

data.loc[:3]
#data.iloc[:3]
#data[:3]       ## = fonction iloc
# Out:
#     show_id     type                                    title  \
# 0  81145628    Movie  Norm of the North: King Sized Adventure
# 1  80117401    Movie               Jandino: Whatever it Takes
# 2  70234439  TV Show                       Transformers Prime
#
#                    director  \
# 0  Richard Finn, Tim Maltby
# 1                       NaN
# 2                       NaN
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 1                                   Jandino Asporaat
# 2  Peter Cullen, Sumalee Montano, Frank Welker, J...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
# 1                            United Kingdom  September 9, 2016          2016
# 2                             United States  September 8, 2018          2013
#
#      rating  duration                           listed_in  \
# ...

# %%
# -> Locasise une categorie d'un DataFrame
# renvoie sous forme de series

data['listed_in']
#data.listed_in
# Out:
# 0                      Children & Family Movies, Comedies
# 1                                         Stand-Up Comedy
# 2                                                Kids' TV
# 3                                                Kids' TV
# 4                                                Comedies
#                               ...
# 6229    TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 6230                                          TV Comedies
# 6231                                               Movies
# 6232             British TV Shows, TV Comedies, TV Dramas
# 6233                       Classic & Cult TV, TV Comedies
# Name: listed_in, Length: 6234, dtype: object

# %%
# -> Locasise plusieur lignes d'une categorie d'une Serie ou d'un DataFrame
# renvoie sous forme de series

data.loc[:3]['listed_in']
#data.iloc[:3]['listed_in']
#data.listed_in[:3]       ## = fonction iloc
# Out:
# 0    Children & Family Movies, Comedies
# 1                       Stand-Up Comedy
# 2                              Kids' TV
# Name: listed_in, dtype: object

# %%
# -> Locasise plusieurs categories d'un DataFrame
# renvoie sous forme de DataFrame

data[['show_id','listed_in']]
# Out:
#        show_id                                          listed_in
# 0     81145628                 Children & Family Movies, Comedies
# 1     80117401                                    Stand-Up Comedy
# 2     70234439                                           Kids' TV
# 3     80058654                                           Kids' TV
# 4     80125979                                           Comedies
# ...        ...                                                ...
# 6229  80000063  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 6230  70286564                                        TV Comedies
# 6231  80116008                                             Movies
# 6232  70281022           British TV Shows, TV Comedies, TV Dramas
# 6233  70153404                     Classic & Cult TV, TV Comedies
#
# [6234 rows x 2 columns]

# %%
# -> Locasise plusieur lignes de plusieur categorie d'un DataFrame
# renvoie sous forme de DataFrame

data[['show_id', 'listed_in']][:3]
# Out:
#     show_id                           listed_in
# 0  81145628  Children & Family Movies, Comedies
# 1  80117401                     Stand-Up Comedy
# 2  70234439                            Kids' TV

# %%
# -> Locasise une ligne d'une Serie ou d'un DataFrame avec condition
# renvoie sous forme de DataFrame

data[data['show_id']== 81145628]
# Out:
#     show_id   type                                    title  \
# 0  81145628  Movie  Norm of the North: King Sized Adventure
#
#                    director  \
# 0  Richard Finn, Tim Maltby
#
#                                                 cast  \
# 0  Alan Marriott, Andrew Toth, Brian Dobson, Cole...
#
#                                     country         date_added  release_year  \
# 0  United States, India, South Korea, China  September 9, 2019          2019
#
#   rating duration                           listed_in  \
# 0  TV-PG   90 min  Children & Family Movies, Comedies
#
#                                          description
# 0  Before planning an awesome wedding for his gra...

# %%
# Creer un DataFrame vide avec 2 colonnes ->

pd.DataFrame(columns = ['show_id', 'listed_in'])
# Out:
# Empty DataFrame
# Columns: [show_id, listed_in]
# Index: []

# %%
# Creer un DataFrame avec 2 colonnes show_id et listed_in ->

pd.DataFrame({'show_id':data['show_id'], 'listed_in':data['listed_in']})
#data[['show_id','listed_in']]
# Out:
#        show_id                                          listed_in
# 0     81145628                 Children & Family Movies, Comedies
# 1     80117401                                    Stand-Up Comedy
# 2     70234439                                           Kids' TV
# 3     80058654                                           Kids' TV
# 4     80125979                                           Comedies
# ...        ...                                                ...
# 6229  80000063  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 6230  70286564                                        TV Comedies
# 6231  80116008                                             Movies
# 6232  70281022           British TV Shows, TV Comedies, TV Dramas
# 6233  70153404                     Classic & Cult TV, TV Comedies
#
# [6234 rows x 2 columns]

# %%
# Creer un DataFrame avec 2 colonnes show_id et listed_in et assigne des variables ->

pd.DataFrame({"show_id": liste4, "listed_in": liste3})
# !! nom des colonnes facultatif !! 
# pd.DataFrame({'show_id': liste1, 'listed_in': liste2}, columns = ['show_id', 'listed_in'])


data[['show_id','listed_in']]
# Out:
#        show_id                                          listed_in
# 0     81145628                 Children & Family Movies, Comedies
# 1     80117401                                    Stand-Up Comedy
# 2     70234439                                           Kids' TV
# 3     80058654                                           Kids' TV
# 4     80125979                                           Comedies
# ...        ...                                                ...
# 6229  80000063  TV Action & Adventure, TV Comedies, TV Sci-Fi ...
# 6230  70286564                                        TV Comedies
# 6231  80116008                                             Movies
# 6232  70281022           British TV Shows, TV Comedies, TV Dramas
# 6233  70153404                     Classic & Cult TV, TV Comedies
#
# [6234 rows x 2 columns]

# %%
# correction Souad :
cat.iloc[0,0]
# Out:
# 81145628

# %%
cat.iloc[0,1].split(", ")
# Out:
# ['Children & Family Movies', 'Comedies']

# %%
liste1 = cat.iloc[0,1].split(", ")

# %%
liste2 = [cat.iloc[0,0] for i in range(len(liste1))]

# %%
liste1
# Out:
# ['Children & Family Movies', 'Comedies']

# %%
liste2
# Out:
# [81145628, 81145628]

# %%
liste3 = []
liste4 = []

for j in range(cat.shape[0]):
    liste3 += cat.iloc[j,1].split(", ")
    liste4 += [cat.iloc[j,0] for i in range(len(cat.iloc[j,1].split(", ")))]
    
show_listed_in = pd.DataFrame({"show_id": liste4, "listed_in": liste3})

# %%
show_listed_in
# Out:
#         show_id                 listed_in
# 0      81145628  Children & Family Movies
# 1      81145628                  Comedies
# 2      80117401           Stand-Up Comedy
# 3      70234439                  Kids' TV
# 4      80058654                  Kids' TV
# ...         ...                       ...
# 13665  70281022          British TV Shows
# 13666  70281022               TV Comedies
# 13667  70281022                 TV Dramas
# 13668  70153404         Classic & Cult TV
# 13669  70153404               TV Comedies
#
# [13670 rows x 2 columns]

# %%
show_listed_in['listed_in'].drop_duplicates()
# Out:
# 0           Children & Family Movies
# 1                           Comedies
# 2                    Stand-Up Comedy
# 3                           Kids' TV
# 6                     Crime TV Shows
# 7             International TV Shows
# 8          Spanish-Language TV Shows
# 9               International Movies
# 10                  Sci-Fi & Fantasy
# 11                         Thrillers
# 13                        Docuseries
# 14               Science & Nature TV
# 15                Action & Adventure
# 19                            Dramas
# 28                       Cult Movies
# 30                Independent Movies
# 33                   Romantic Movies
# 37                     Documentaries
# 38                     Horror Movies
# 46                 Romantic TV Shows
# 47                       TV Comedies
# 77                         TV Dramas
# 78                      TV Thrillers
# 129                     TV Mysteries
# 143                 British TV Shows
# ...

# %%
listed_in = show_listed_in['listed_in'].drop_duplicates()
listed_in.count()
# Out:
# 42
