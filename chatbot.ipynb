# %%
import random


phrase_1 = ["Comment allez-vous ?", "Pourquoi venez vous me voir ?", "Comment c'est passez votre journée ?"]


rep_2 = ["Pourquoi me posez-vous cette question ?", "Oseriez-vous poser cette question à un humain ?", "Je ne peut malheureusement pas répondre à cette question."]

rep_3 = ["J'entends bien.", "Je sens une pointe de regret.", "Est-ce une bonne nouvelle ?", "OUI, c'est ca le problème.", "Pensez-vous ce que vous dites ?", "Hum... il se peut."]



def rep(liste):
    random_rep = random.randint(0, len(liste) - 1)
    reponse = liste[random_rep]
    return reponse



print(rep(phrase_1))
#user_rep = input("C'est à vous de parler : ")
user_rep = input("")



while user_rep != "Q":
    user_rep = input("C'est à vous de parler : ")
    
    mot_cle = ["père", "mére", "copain", "copine", "maman", "papa", "ami", "amie"]
    u = ""
    for mot in mot_cle :
        #print(user_rep.find(i))
        if user_rep.find(mot) > 0:
            u = mot
            #print(u)
            
    if len(u) > 0 : 

        rep_D = ["Comment va votre {0} ?".format(u), "La relation avec votre {0} vous pose-t-elle problème ?".format(u), "Pourquoi pensez-vous en ce moment à votre {0}".format(u)]
        print(rep(rep_D))
    
    else :
        if user_rep.find("?") > 0:
             print(rep(rep_2))
        
        else:
            print(rep(rep_3))

"""
for i in range(10): 
    phrase = input() 
    # test sur le mot-clé 
   
    motclefs = ["père","mère","copain", "copine", "maman", "papa", "ami", "amie"] 
    found = "" 
    for motc in motclefs : 
        if phrase.find(motc) > 0 : 
            found = motc 
    
    if len(found) > 0 : 
        k = random.randint(0,len(RepPERE)-1) 
        reponse = RepPERE[k] 
        print("@@ ",reponse.format(found)) 
 
    else : 
        # est-ce une question ? 
        
        if phrase.find("?") > 0 : 
            k = random.randint(0,len(Questions)-1) 
            print("@@ ",Questions[k]) 
        
        else : 
            # vite une phrase vague : 
            k = random.randint(0,len(Vagues)-1) 
            print("@@ ",Vagues[k])

"""



"""    
        elif "?" in user_rep and i not in mot_cle:
            print(rep(rep_2))
            

        else:
            print(rep(rep_3))
            


    user_rep = input("C'est à vous de parler : ")
"""
# Out:
# Comment allez-vous ?
# salut mec
# C'est à vous de parler : ca va ete toi?
# Je ne peut malheureusement pas répondre à cette question.
# C'est à vous de parler : comment va ton papa
# Comment va votre papa ?
# C'est à vous de parler : comment va ton papa?
# Comment va votre papa ?
# C'est à vous de parler : ca va?
# Je ne peut malheureusement pas répondre à cette question.
